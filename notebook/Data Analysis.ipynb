# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data_path = os.path.join(os.pardir, 'data')

# %%
weather_path = os.path.join(data_path, "Cleaned Data/weather_final.csv")
state_path = os.path.join(data_path, "Cleaned Data/state_final.csv")
soil_path = os.path.join(data_path, "Cleaned Data/soil_final.csv")

# %%
weather_df = pd.read_csv(weather_path)
soil_df = pd.read_csv(soil_path)
state_df = pd.read_csv(state_path)

# %%
weather_df.district.unique(), len(weather_df.district.unique())
# Out:
# (array(['bankura', 'birbhum', 'coochbehar', 'dinajpur dakshin',
#         'darjeeling', 'howrah', 'hooghly', 'jalpaiguri', 'malda',
#         'murshidabad', 'nadia', '24 paraganas north', 'paschim bardhaman',
#         'medinipur west', 'purba bardhaman', 'medinipur east', 'purulia',
#         '24 paraganas south', 'dinajpur uttar'], dtype=object),
#  19)

# %%
soil_df.Dist_Name.unique(), len(soil_df.Dist_Name.unique())
# Out:
# (array(['nadia', 'murshidabad', 'birbhum', 'bankura', 'hooghly', 'howrah',
#         'jalpaiguri', 'darjeeling', 'malda', 'coochbehar', 'purulia',
#         '24 paraganas north', '24 paraganas south', 'dinajpur uttar',
#         'dinajpur dakshin', 'medinipur east', 'medinipur west',
#         'paschim bardhaman', 'purba bardhaman'], dtype=object),
#  19)

# %%
state_df.district.unique(), len(state_df.district.unique())
# Out:
# (array(['24 paraganas north', '24 paraganas south', 'bankura', 'birbhum',
#         'coochbehar', 'darjeeling', 'dinajpur dakshin', 'dinajpur uttar',
#         'hooghly', 'howrah', 'jalpaiguri', 'malda', 'medinipur east',
#         'medinipur west', 'murshidabad', 'nadia', 'purba bardhaman',
#         'purulia', 'paschim bardhaman'], dtype=object),
#  19)

# %%
state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12323 entries, 0 to 12322
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   district                12323 non-null  object
#  1   year                    12323 non-null  int64
#  2   Season                  12323 non-null  object
#  3   Area (Hectare)          12323 non-null  float64
#  4   Production (Tonnes)     12307 non-null  float64
#  5   Yield (Tonnes/Hectare)  12323 non-null  float64
#  6   Crop                    12323 non-null  object
#  7   State                   12323 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 770.3+ KB

# %%
soil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Dist_Code                    19 non-null     int64
#  1   State_Code                   19 non-null     int64
#  2   State_Name                   19 non-null     object
#  3   Dist_Name                    19 non-null     object
#  4   SOIL_TYPE_PERCENT_(Percent)  19 non-null     object
#  5   ORTHIDS                      9 non-null      float64
#  6   UDUPTS/UDALFS                8 non-null      float64
#  7   USTALF/USTOLLS               3 non-null      float64
#  8   INCEPTISOLS                  7 non-null      float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.5+ KB

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 34 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   year                                            494 non-null    int64
#  1   mean_temperature_2m_max (Â°C)_quarter1          494 non-null    float64
#  2   mean_temperature_2m_max (Â°C)_quarter2          494 non-null    float64
#  3   mean_temperature_2m_max (Â°C)_quarter3          494 non-null    float64
#  4   mean_temperature_2m_max (Â°C)_quarter4          494 non-null    float64
#  5   mean_temperature_2m_min (Â°C)_quarter1          494 non-null    float64
#  6   mean_temperature_2m_min (Â°C)_quarter2          494 non-null    float64
#  7   mean_temperature_2m_min (Â°C)_quarter3          494 non-null    float64
#  8   mean_temperature_2m_min (Â°C)_quarter4          494 non-null    float64
# ...

# %%
weather_df.describe()
# Out:
#               year  mean_temperature_2m_max (Â°C)_quarter1  \
# count   494.000000                              494.000000
# mean   2009.500000                               27.205986
# std       7.507603                                3.827312
# min    1997.000000                               10.526667
# 25%    2003.000000                               26.848077
# 50%    2009.500000                               28.071667
# 75%    2016.000000                               28.962778
# max    2022.000000                               31.304444
#
#        mean_temperature_2m_max (Â°C)_quarter2  \
# count                              494.000000
# mean                                33.126663
# std                                  3.976177
# min                                 17.156044
# 25%                                 32.656593
# 50%                                 33.976374
# 75%                                 35.256319
# max                                 38.731868
#
# ...

# %%
state_df.describe()
# Out:
#                year  Area (Hectare)  Production (Tonnes)  \
# count  12323.000000    1.232300e+04         1.230700e+04
# mean    2007.882172    1.916854e+04         7.220320e+05
# std        6.576426    1.431017e+05         4.937430e+06
# min     1997.000000    1.000000e+00         7.040000e-01
# 25%     2002.000000    1.080000e+02         9.800000e+01
# 50%     2008.000000    5.960000e+02         8.400000e+02
# 75%     2014.000000    4.657000e+03         1.749900e+04
# max     2019.000000    8.580100e+06         7.509500e+07
#
#        Yield (Tonnes/Hectare)
# count            12323.000000
# mean               427.252544
# std               2356.444016
# min                  0.000000
# 25%                  0.680876
# 50%                  1.198830
# 75%                  2.710030
# max              38800.000000

# %%
weather_df[weather_df.district == "bankura"].year.unique()
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022], dtype=int64)

# %%
state_df.shape, weather_df.shape, soil_df.shape
# Out:
# ((12323, 8), (494, 34), (19, 9))

# %%
merged_df = pd.merge(state_df, weather_df , on=['district', 'year'])
merged_df.shape
# Out:
# (12323, 40)

# %%
# state_df[(state_df.district== "bankura") & (state_df.Crop == "Bajra")]

# %%
# merged_df[(merged_df.district== "bankura") & (merged_df.Crop == "Bajra")]

# %%
#   from ydata_profiling import ProfileReport
# r = ProfileReport(merged_df)
# r.to_file(output_file='cropanalysis.html')

# %%
# sns.lineplot(data=merged_df, x='year',y="Yield (Tonnes/Hectare)")# y="Production (Tonnes)")

# %%
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=merged_df, x='year',y="Production (Tonnes)", hue="Crop")
# plt.title('Year-wise Production of Each Crop')
# plt.xlabel('Year')
# plt.ylabel('Production')
# plt.legend(title='Crop')
# plt.grid(True)
# plt.show()

# %%
merged_df[merged_df.Crop == "Arecanut"]['Production (Tonnes)'].describe()
# Out:
# count      188.000000
# mean      1482.659574
# std       6783.420587
# min          2.000000
# 25%         78.750000
# 50%        383.000000
# 75%       1317.750000
# max      92000.000000
# Name: Production (Tonnes), dtype: float64

# %%
merged_df[merged_df.Crop != "Arecanut"]['Production (Tonnes)'].describe()
# Out:
# count    1.211900e+04
# mean     7.332097e+05
# std      4.974760e+06
# min      7.040000e-01
# 25%      9.800000e+01
# 50%      8.550000e+02
# 75%      1.858100e+04
# max      7.509500e+07
# Name: Production (Tonnes), dtype: float64

# %%
# merged_df[merged_df["Production (Tonnes)"] >18581.0]

# %%
num_plots = len(merged_df.Crop.unique())
cols = 2 # Define the number of columns
rows = (num_plots // cols) + (num_plots % cols > 0)  # Calculate the required rows

fig, axes = plt.subplots(rows, cols, figsize=(15, 30), constrained_layout=True)
axes = axes.flatten()

# Plot each crop's data in a separate subplot
for i, (crop, crop_data) in enumerate(merged_df.groupby('Crop')):
    if i >= num_plots:
        break  # Stop if we exceed the number of required subplots
    
    sns.lineplot(data=crop_data, x='year', y='Production (Tonnes)', ax=axes[i], marker='o')
    axes[i].set_title(crop)
    axes[i].set_xlabel('Year')
    axes[i].set_ylabel('Production')

# Turn off any remaining empty subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.suptitle('Year-wise Production for Each Crop', fontsize=12)
plt.show()

# %%
merged_df[merged_df["Crop"]=='Garlic'].year.unique()
# Out:
# array([2007], dtype=int64)

# %%
merged_df[merged_df["Crop"]=='Oilseeds'].year.unique()
# Out:
# array([1997], dtype=int64)

# %%
sns.scatterplot(data=merged_df, x='Production (Tonnes)', y="")

# %%
# Yield per Hectare Analysis
avg_yield = merged_df.groupby('Crop')['Yield (Tonnes/Hectare)'].mean().sort_values(ascending=False)
print(avg_yield)
# Out:
# Crop
# Coconut                  12473.516391
# Sugarcane                   83.496773
# Potato                      23.493907
# Jute                        15.531965
# Garlic                      10.537881
# Mesta                        9.839236
# Sannhamp                     4.844056
# Maize                        3.002221
# Cotton(lint)                 2.652120
# Rice                         2.531386
# Wheat                        2.303367
# Arecanut                     2.003294
# Turmeric                     1.784816
# Ginger                       1.666708
# Groundnut                    1.567903
# Barley                       1.309445
# Sunflower                    1.166366
# Arhar/Tur                    1.058496
# Dry chillies                 1.030352
# Gram                         0.974667
# Khesari                      0.935802
# Peas & beans (Pulses)        0.931033
# Tobacco                      0.903944
# Moth                         0.888542
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=merged_df, x='district', y='Yield (Tonnes/Hectare)')#, hue='Crop')
plt.title('Yield by District')
plt.xticks(rotation=90)
plt.show()

# %%
# Example: scatter plot for temperature range impact on yield
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df, x='mean_temperature_2m_max (Â°C)_quarter1', y='Yield (Tonnes/Hectare)')
plt.title('Impact of Temperature on Yield')
plt.xlabel('Temperature Max Quarter 1 (°C)')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.show()

# %%
# Temperature trend over the years for each quarter
temp_mean_cols = [col for col in merged_df.columns if 'mean_temperature_2m_mean' in col]
for quarter in temp_mean_cols:
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=merged_df, x='year', y=quarter)
    plt.title(f'Average {quarter} Temperature by Year')
    plt.xlabel('Year')
    plt.ylabel('Temperature (°C)')
    plt.show()

# %%
# Average rainfall by year in each quarter
rain_columns = temp_mean_cols = [col for col in merged_df.columns if 'rain' in col]
for quarter in rain_columns:
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=merged_df, x='year', y=quarter)
    plt.title(f'Average {quarter} Rainfall by Year')
    plt.xlabel('Year')
    plt.ylabel('Rainfall (mm)')
    plt.show()

# %%
# Analysis of production by season and temperature
sns.boxplot(data=merged_df, x='Season', y='Production (Tonnes)')# hue='Crop')
plt.title('Seasonal Production by Crop')
plt.xlabel('Season')
plt.ylabel('Production (Tonnes)')
plt.legend(title='Crop')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Scatter plot for rainfall vs. production
rain_columns = [col for col in merged_df.columns if 'mean_rain_sum' in col]
for quarter in rain_columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=merged_df, x=quarter, y='Production (Tonnes)', hue='Crop')
    plt.title(f'Impact of {quarter} Rainfall on Production')
    plt.xlabel(f'{quarter} (mm)')
    plt.ylabel('Production (Tonnes)')
    plt.legend(title='Crop')
    plt.show()

# %%
# Correlation heatmap for temperature and yield
temp_columns = [col for col in merged_df.columns if 'mean_temperature_2m_mean' in col]
climate_yield_data = merged_df[temp_columns + ['Yield (Tonnes/Hectare)']].corr()
sns.heatmap(climate_yield_data, annot=True, cmap='coolwarm')
plt.title('Correlation Between Temperature and Yield')
plt.show()

# %%
# Correlation heatmap for temperature and yield
temp_columns = [col for col in merged_df.columns if 'mean_temperature_2m_mean' in col]
climate_yield_data = merged_df[temp_columns + ['Production (Tonnes)']].corr()
sns.heatmap(climate_yield_data, annot=True, cmap='coolwarm')
plt.title('Correlation Between Temperature and Yield')
plt.show()

# %%
merged_df.to_csv(os.path.join(data_path,"Cleaned Data/merged_final.csv"), index=False)
